# %% [raw]
# ---
# title: "Jupyter Lab Test"
# date: 11/01/2025
# format:
#     html:
#         code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## This is a JupyterLab Test
# I'm going to see what I can do here.
# the following is a test
# ## Polar Axis
#
# For a demonstration of a line plot on a polar axis, see @fig-polar.

# %%
#| label: fig-polar
#| fig-cap: "A line plot on a polar axis"

import sys
# %pip install numpy
# %pip install matplotlib
import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rticks([0.5, 1, 1.5, 2])
ax.grid(True)
plt.show()
# Out:
# Requirement already satisfied: numpy in /Users/zackmoore/Library/Python/3.14/lib/python/site-packages (2.3.4)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 get_ipython().run_line_magic('pip', 'install numpy')
#       6 import numpy as np
# ----> 7 import matplotlib.pyplot as plt
#       9 r = np.arange(0, 2, 0.01)
#      10 theta = 2 * np.pi * r
#
# ModuleNotFoundError: No module named 'matplotlib'
